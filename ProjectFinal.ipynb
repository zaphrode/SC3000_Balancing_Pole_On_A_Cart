# %%
# !pip install gym
# !pip install stable-baselines3
# !pip install matplotlib
# !pip install torch
# !pip install IPython
# Out:
# Requirement already satisfied: gym in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (0.25.2)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from gym) (4.11.3)
# Requirement already satisfied: gym-notices>=0.0.4 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from gym) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from gym) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from gym) (1.23.5)
# Requirement already satisfied: zipp>=0.5 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gym) (3.8.0)
# Requirement already satisfied: stable-baselines3 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: torch>=1.13 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: pandas in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (1.4.4)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (1.23.5)
# Requirement already satisfied: cloudpickle in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (2.0.0)
# Requirement already satisfied: matplotlib in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (3.5.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.10.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.11.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: networkx in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (2.8.4)
# Requirement already satisfied: filelock in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (3.6.0)
# Requirement already satisfied: jinja2 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (2.11.3)
# Requirement already satisfied: fsspec in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (2022.7.1)
# Requirement already satisfied: sympy in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (1.10.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from pandas->stable-baselines3) (2022.1)
# Requirement already satisfied: zipp>=0.5 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3) (3.8.0)
# Requirement already satisfied: six>=1.5 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.13->stable-baselines3) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.13->stable-baselines3) (1.2.1)
# Requirement already satisfied: matplotlib in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: six>=1.5 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: torch in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: jinja2 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch) (2.11.3)
# Requirement already satisfied: fsspec in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch) (2022.7.1)
# Requirement already satisfied: sympy in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch) (1.10.1)
# Requirement already satisfied: networkx in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch) (2.8.4)
# Requirement already satisfied: filelock in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from torch) (4.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from sympy->torch) (1.2.1)
# Requirement already satisfied: IPython in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (7.31.1)
# Requirement already satisfied: backcall in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (69.2.0)
# Requirement already satisfied: appnope in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (4.8.0)
# Requirement already satisfied: pygments in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (2.15.1)
# Requirement already satisfied: jedi>=0.16 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (3.0.20)
# Requirement already satisfied: decorator in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/nahid/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# ERROR: Could not find a version that satisfies the requirement io (from versions: none)
# ERROR: No matching distribution found for io

# %%
import gym
from gym.wrappers import RecordVideo
#from stable_baselines3 import PPO
#from stable_baselines3.common.vec_env import DummyVecEnv
##from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt
import torch
import glob
from IPython.display import HTML
from IPython import display as ipythondisplay
import io
import base64
import numpy as np

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)

# %%
torch.cuda.is_available()
print(torch.version.cuda)
# Out:
# None

# %%
# Initialize the Q-table
q_table = np.random.uniform(low=-1, high=1, size=([20,20,20,20] + [env.action_space.n]))

# Set hyperparameters
num_episodes = 30000
epsilon = 0.25
learning_rate = 0.2
discount_factor = 0.995

# Define the bins for discretizing the continuous state space
def get_bins():
    return [
        np.linspace(-4.8, 4.8, num=20),
        np.linspace(-4, 4, num=20),
        np.linspace(-0.418, 0.418, num=20),
        np.linspace(-4, 4, num=20)
    ]

# Discretize the state space
def discretize_state(state, bins):
    index = []
    for i in range(len(state)):
        index.append(np.digitize(state[i], bins[i]) - 1)
    return tuple(index)

# Choose an action based on the Q-values
def select_action(state, q_table, eps):
    if np.random.uniform() < eps:
        return env.action_space.sample()
    else:
        return np.argmax(q_table[state])

# Update the Q-table based on the observed state, action, next state, and reward
def update_q_table(q_table, state, action, next_state, reward, lr, gamma):
    old_value = q_table[state + (action,)]
    next_max = np.max(q_table[next_state])
    new_value = (1 - lr) * old_value + lr * (reward + gamma * next_max)
    q_table[state + (action,)] = new_value
    return q_table

# Run a single episode and return the total reward
def run_episode(env, q_table, eps, bins):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        state = discretize_state(obs, bins)
        action = select_action(state, q_table, eps)
        obs, reward, done, _ = env.step(action)
        next_state = discretize_state(obs, bins)
        q_table = update_q_table(q_table, state, action, next_state, reward, learning_rate, discount_factor)
        total_reward += reward
    return total_reward

# Train the agent for a specified number of episodes
def train_agent(env, q_table, num_episodes, eps, bins):
    rewards = []
    for i in range(num_episodes):
        total_reward = run_episode(env, q_table, eps, bins)
        rewards.append(total_reward)
        if (i + 1) % 100 == 0:
            avg_reward = np.mean(rewards[-100:])
            print(f"Episode {i+1}/{num_episodes}, average reward: {avg_reward:.2f}")
    return q_table, rewards

# Train the agent
q_table_trained, rewards = train_agent(env, q_table, num_episodes, epsilon, get_bins())
# Out:
# Episode 100/30000, average reward: 25.73
# Episode 200/30000, average reward: 28.37
# Episode 300/30000, average reward: 66.07
# Episode 400/30000, average reward: 101.61
# Episode 500/30000, average reward: 117.20
# Episode 600/30000, average reward: 118.45
# Episode 700/30000, average reward: 123.57
# Episode 800/30000, average reward: 134.51
# Episode 900/30000, average reward: 148.26
# Episode 1000/30000, average reward: 124.09
# Episode 1100/30000, average reward: 151.03
# Episode 1200/30000, average reward: 139.77
# Episode 1300/30000, average reward: 114.69
# Episode 1400/30000, average reward: 135.07
# Episode 1500/30000, average reward: 149.31
# Episode 1600/30000, average reward: 129.14
# Episode 1700/30000, average reward: 156.71
# Episode 1800/30000, average reward: 132.17
# Episode 1900/30000, average reward: 151.16
# Episode 2000/30000, average reward: 170.27
# Episode 2100/30000, average reward: 153.53
# Episode 2200/30000, average reward: 180.65
# Episode 2300/30000, average reward: 151.38
# Episode 2400/30000, average reward: 176.50
# Episode 2500/30000, average reward: 201.30
# Episode 2600/30000, average reward: 177.60
# Episode 2700/30000, average reward: 188.08
# Episode 2800/30000, average reward: 169.36
# Episode 2900/30000, average reward: 199.98
# Episode 3000/30000, average reward: 199.61
# Episode 3100/30000, average reward: 191.42
# Episode 3200/30000, average reward: 223.66
# Episode 3300/30000, average reward: 187.69
# Episode 3400/30000, average reward: 179.10
# Episode 3500/30000, average reward: 223.83
# Episode 3600/30000, average reward: 196.59
# Episode 3700/30000, average reward: 212.41
# Episode 3800/30000, average reward: 184.48
# Episode 3900/30000, average reward: 217.30
# Episode 4000/30000, average reward: 209.54
# Episode 4100/30000, average reward: 218.87
# Episode 4200/30000, average reward: 213.10
# Episode 4300/30000, average reward: 241.05
# Episode 4400/30000, average reward: 222.58
# Episode 4500/30000, average reward: 211.19
# Episode 4600/30000, average reward: 184.07
# Episode 4700/30000, average reward: 224.11
# Episode 4800/30000, average reward: 209.75
# Episode 4900/30000, average reward: 245.27
# Episode 5000/30000, average reward: 240.09
# Episode 5100/30000, average reward: 226.52
# Episode 5200/30000, average reward: 221.32
# Episode 5300/30000, average reward: 196.12
# Episode 5400/30000, average reward: 217.43
# Episode 5500/30000, average reward: 187.79
# Episode 5600/30000, average reward: 209.32
# Episode 5700/30000, average reward: 220.01
# Episode 5800/30000, average reward: 242.78
# Episode 5900/30000, average reward: 205.30
# Episode 6000/30000, average reward: 201.17
# %%
import matplotlib.pyplot as plt

# Calculate the average reward per 100 episodes
avg_rewards = [np.mean(rewards[i:i+100]) for i in range(0, num_episodes, 100)]

# Plot the graph
plt.plot(range(0, num_episodes, 100), avg_rewards)
plt.xlabel('Timesteps')
plt.ylabel('Average reward')
plt.title("Average reward per 100 episode for each X timesteps used for training")
plt.show()

# %%
#TASK 1

# %%
# Reset the environment to get the initial observation
observation = env.reset()

# Use the bins to discretize the observation space
bins = get_bins()  # Ensure this uses the same bins as during training

# Discretize the state using the observation
state = discretize_state(observation, bins)

# Select the best action from the Q-table using the current state
# Note: No need for _, as we directly access the Q-table
action = np.argmax(q_table_trained[state])

print("Observation space is: ", observation)
print("Action taken is: ", action)
# Out:
# Observation space is:  [-0.00424028  0.00230707  0.01476783 -0.03720753]
# Action taken is:  0

# %%
#TASK 2

# %%
# Function to run a single episode using the trained Q-table, and return the total reward
def test_episode(env, q_table, bins):
    score = 0  # Initialize total reward for the episode
    obs = env.reset()  # Reset the environment to start a new episode
    done = False  # Initialize the 'done' condition
    while not done:
        # Discretize the state using the same bins as during training
        state = discretize_state(obs, bins)
        # Select the best action from the Q-table using the current state
        action = np.argmax(q_table[state])
        # Apply the action in the environment
        obs, reward, done, info = env.step(action)
        # Update the total reward
        score += reward
    return score

# Evaluate the trained Q-learning agent over a certain number of episodes
def evaluate_agent(env, q_table, num_episodes, bins):
    sum_episode_scores = []  # List to hold the total reward for each episode
    for episode in range(1, num_episodes + 1):
        # Run a single episode and get the total reward
        score = test_episode(env, q_table, bins)
        print(f'Episode: {episode}, Score: {score}')
        sum_episode_scores.append(score)  # Append the score for the episode to the list
    return sum_episode_scores

# Use the bins from training for discretization
bins = get_bins()

# Number of episodes to evaluate
num_test_episodes = 100

# Evaluate the agent
sum_episode_scores = evaluate_agent(env, q_table_trained, num_test_episodes, bins)

# Calculate and print the average score
average_score = np.mean(sum_episode_scores)
print(f"Average score over {num_test_episodes} episodes: {average_score:.2f}")
# Out:
# Episode: 1, Score: 500.0
# Episode: 2, Score: 500.0
# Episode: 3, Score: 500.0
# Episode: 4, Score: 500.0
# Episode: 5, Score: 500.0
# Episode: 6, Score: 500.0
# Episode: 7, Score: 500.0
# Episode: 8, Score: 500.0
# Episode: 9, Score: 500.0
# Episode: 10, Score: 500.0
# Episode: 11, Score: 500.0
# Episode: 12, Score: 500.0
# Episode: 13, Score: 500.0
# Episode: 14, Score: 500.0
# Episode: 15, Score: 500.0
# Episode: 16, Score: 500.0
# Episode: 17, Score: 500.0
# Episode: 18, Score: 500.0
# Episode: 19, Score: 500.0
# Episode: 20, Score: 500.0
# Episode: 21, Score: 500.0
# Episode: 22, Score: 500.0
# Episode: 23, Score: 500.0
# Episode: 24, Score: 500.0
# Episode: 25, Score: 500.0
# Episode: 26, Score: 500.0
# Episode: 27, Score: 500.0
# Episode: 28, Score: 500.0
# Episode: 29, Score: 500.0
# Episode: 30, Score: 500.0
# Episode: 31, Score: 500.0
# Episode: 32, Score: 500.0
# Episode: 33, Score: 500.0
# Episode: 34, Score: 500.0
# Episode: 35, Score: 500.0
# Episode: 36, Score: 500.0
# Episode: 37, Score: 500.0
# Episode: 38, Score: 500.0
# Episode: 39, Score: 500.0
# Episode: 40, Score: 500.0
# Episode: 41, Score: 500.0
# Episode: 42, Score: 500.0
# Episode: 43, Score: 500.0
# Episode: 44, Score: 500.0
# Episode: 45, Score: 500.0
# Episode: 46, Score: 500.0
# Episode: 47, Score: 500.0
# Episode: 48, Score: 500.0
# Episode: 49, Score: 500.0
# Episode: 50, Score: 500.0
# Episode: 51, Score: 500.0
# Episode: 52, Score: 500.0
# Episode: 53, Score: 500.0
# Episode: 54, Score: 500.0
# Episode: 55, Score: 500.0
# Episode: 56, Score: 252.0
# Episode: 57, Score: 500.0
# Episode: 58, Score: 500.0
# Episode: 59, Score: 500.0
# Episode: 60, Score: 500.0
# Episode: 61, Score: 500.0
# Episode: 62, Score: 500.0
# Episode: 63, Score: 500.0
# Episode: 64, Score: 500.0
# Episode: 65, Score: 500.0
# Episode: 66, Score: 500.0
# Episode: 67, Score: 500.0
# Episode: 68, Score: 500.0
# Episode: 69, Score: 500.0
# Episode: 70, Score: 500.0
# Episode: 71, Score: 500.0
# Episode: 72, Score: 500.0
# Episode: 73, Score: 500.0
# Episode: 74, Score: 500.0
# Episode: 75, Score: 257.0
# Episode: 76, Score: 500.0
# Episode: 77, Score: 500.0
# Episode: 78, Score: 500.0
# Episode: 79, Score: 500.0
# Episode: 80, Score: 500.0
# Episode: 81, Score: 500.0
# Episode: 82, Score: 500.0
# Episode: 83, Score: 500.0
# Episode: 84, Score: 386.0
# Episode: 85, Score: 500.0
# Episode: 86, Score: 500.0
# Episode: 87, Score: 500.0
# Episode: 88, Score: 500.0
# Episode: 89, Score: 500.0
# Episode: 90, Score: 500.0
# Episode: 91, Score: 500.0
# Episode: 92, Score: 500.0
# Episode: 93, Score: 240.0
# Episode: 94, Score: 500.0
# Episode: 95, Score: 500.0
# Episode: 96, Score: 500.0
# Episode: 97, Score: 500.0
# Episode: 98, Score: 500.0
# Episode: 99, Score: 500.0
# Episode: 100, Score: 500.0
# Average score over 100 episodes: 491.35

# %%
# Plotting the cumulative reward for each episode
plt.plot(sum_episode_scores)
plt.title("Cumulative reward for each episode")
plt.ylabel("Cumulative reward")
plt.xlabel("Episode")
plt.show()

# Don't forget to close the environment when done
env.close()

# %%
#TASK 3

# %%
from IPython import display as ipythondisplay

# Function to display the recorded video
def show_video():
    ipythondisplay.clear_output(wait=True)
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                     loop controls style="height: 400px;">
                     <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                     </video>'''.format(encoded.decode('ascii'))))
    else: 
        print("Could not find video")

# %%
# Initialize your environment with video recording
env = RecordVideo(gym.make("CartPole-v1"), "video")

observation = env.reset()
total_reward = 0

# Ensure the bins are defined (same as during training)
bins = get_bins()

while True:
    # Discretize the state using the observation
    state = discretize_state(observation, bins)
    
    # Select the best action from the Q-table using the current state
    action = np.argmax(q_table_trained[state])
    
    # Apply the action in the environment
    observation, reward, done, info = env.step(action)
    total_reward += reward
    
    # Breaking the loop when the episode ends
    if done:
        break

env.close()
# Display the recorded video
show_video()
# Out:
# <video alt="test" autoplay
#                      loop controls style="height: 400px;">
#                      <source src="data:video/mp4;base64,..." type="video/mp4" />
#                      </video>

# %%
print("Episode reward is ", total_reward)
# Out:
# Episode reward is  500.0
